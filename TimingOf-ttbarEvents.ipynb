# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = []
# f = 'data/time_cost.txt'
fname = 'data/timing_study.txt'
with open(fname) as f:
    for line in f:
        data.append(float(line[:-1]))

# %%
plt.plot(data, '-*', lw=2)

# %% [markdown]
# Above plot shows the time it takes to generate 5000 ttbar events using Pythia with 5 different sets of parameters. y-axis in a unit of miniutes

# %%
plt.plot(data, '-*', lw=2)

# %%
data2 = []
# f = 'data/time_cost.txt'
fname2 = 'data/timing_study2.txt'
with open(fname2) as f:
    for line in f:
        data2.append(float(line[:-1]))

# %%
plt.plot(data[:], '-*', lw=2, label='try1')
plt.plot(data2[:], '-*', lw=2, label='try2')

# %%
plt.plot(data[-30:], '-*', lw=2, label='try1')
plt.plot(data2[-30:], '-*', lw=2, label='try2')

# %%
plt.plot(data[:30], '-*', lw=2, label='try1')
plt.plot(data2[:30], '-*', lw=2, label='try2')

# %% [markdown]
# Test the distribution of `rand()/static_cast<double>(RAND_MAX)` from C++

# %%
rand_vals = []
with open("CPP/build/random_test.txt") as f:
    for line in f:
        rand_vals.append(float(line[:-1]))

# %%
plt.hist(rand_vals, range=(0, 1));
