# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y1 = (x-5)**2/1 + 0.2
y2 = (x-7)**2/2 + 0.5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x, y1, label='pdf1')
plt.plot(x, y2, label='pdf2')
plt.ylim(0, 9)
plt.xlim(2, 10)
plt.xlabel('p', fontsize=16)
plt.ylabel('$\chi^{2}$', fontsize=16)
plt.legend()
plt.savefig("demo_chi2.pdf")

# %%
count, bins, _ = plt.hist(-np.log(g1[g1>0]), 30, normed=True, histtype='step')
count, bins, _ = plt.hist(-np.log(g2[g2>0]), 30, normed=True, histtype='step')
